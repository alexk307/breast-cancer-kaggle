# %%
import csv, pandas

# %%
data = pandas.read_csv('data.csv')

# %%
del data['Unnamed: 32']

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
correlation_matrix = data.corr()

# %%
correlation_matrix['area_mean'].sort_values()
# Out:
# fractal_dimension_mean    -0.283110
# smoothness_se             -0.166777
# symmetry_se               -0.072497
# texture_se                -0.066280
# fractal_dimension_se      -0.019887
# fractal_dimension_worst    0.003738
# id                         0.096893
# smoothness_worst           0.123523
# symmetry_worst             0.143570
# symmetry_mean              0.151293
# smoothness_mean            0.177028
# concavity_se               0.207660
# compactness_se             0.212583
# texture_worst              0.287489
# texture_mean               0.321086
# concave points_se          0.372320
# compactness_worst          0.390410
# compactness_mean           0.498502
# concavity_worst            0.512606
# concavity_mean             0.685983
# concave points_worst       0.722017
# perimeter_se               0.726628
# radius_se                  0.732562
# area_se                    0.800086
# concave points_mean        0.823269
# perimeter_worst            0.959120
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,16))
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
data.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %% [markdown]
# Split training data and test data

# %%
training_set, test_set = train_test_split(data, test_size=0.2, random_state=60)

# %%
test_set_labels = test_set.diagnosis.tolist()

# %%
train_set_labels = training_set.diagnosis.tolist()

# %%
del test_set['diagnosis']

# %%
del training_set['diagnosis']

# %%
test_set_data = test_set.values.tolist()
training_set_data = training_set.values.tolist()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe = Pipeline([
    ('scaler', StandardScaler())
])

test_set_data = pipe.fit_transform(test_set_data)
training_set_data = pipe.fit_transform(training_set_data)

# %%
from sklearn import svm

# %%
clf = svm.SVC()

# %%
clf.fit(training_set_data, train_set_labels)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
for i in range(len(test_set_data)):
    print 'predicted: %s, actual: %s' % (clf.predict(test_set_data[i]), test_set_labels[i])
# Out:
# predicted: ['M'], actual: M
# predicted: ['M'], actual: B
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['M'], actual: M
# predicted: ['M'], actual: M
# predicted: ['M'], actual: B
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['M'], actual: M
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# predicted: ['B'], actual: B
# ...
